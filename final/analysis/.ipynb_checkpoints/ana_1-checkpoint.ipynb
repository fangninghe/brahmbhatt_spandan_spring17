# %% [markdown]
# ## Analysis 1
# ### Find the top 10 states with the most HI-B visa opportunities by year

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = pd.read_csv('data/h1b_kaggle.csv',dtype='unicode')
df = pd.DataFrame(file)
df.head()
# Out:
#   Unnamed: 0          CASE_STATUS  \
# 0          1  CERTIFIED-WITHDRAWN
# 1          2  CERTIFIED-WITHDRAWN
# 2          3  CERTIFIED-WITHDRAWN
# 3          4  CERTIFIED-WITHDRAWN
# 4          5            WITHDRAWN
#
#                                        EMPLOYER_NAME  \
# 0                             UNIVERSITY OF MICHIGAN
# 1                             GOODMAN NETWORKS, INC.
# 2                          PORTS AMERICA GROUP, INC.
# 3  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
#   FULL_TIME_POSITION PREVAILING_WAGE  YEAR                 WORKSITE  \
# 0                  N           36067  2016      ANN ARBOR, MICHIGAN
# 1                  Y          242674  2016             PLANO, TEXAS
# 2                  Y          193066  2016  JERSEY CITY, NEW JERSEY
# 3                  Y          220314  2016         DENVER, COLORADO
# 4                  Y        157518.4  2016      ST. LOUIS, MISSOURI
#
#            lon         lat
# 0  -83.7430378  42.2808256
# 1  -96.6988856  33.0198431
# 2  -74.0776417  40.7281575
# 3  -104.990251  39.7392358
# 4  -90.1994042  38.6270025

# %% [markdown]
# ### Data cleaning

# %%
df.shape
# Out:
# (3002458, 11)

# %%
df_nan_drop = df.dropna(0,how='any')
df_nan_drop.shape
# Out:
# (2877765, 11)

# %%
df_step1 = df_nan_drop.drop(df.columns[0], axis=1)    #drop first column with the old index
df_step1.head()
# Out:
#            CASE_STATUS                                      EMPLOYER_NAME  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
#   FULL_TIME_POSITION PREVAILING_WAGE  YEAR                 WORKSITE  \
# 0                  N           36067  2016      ANN ARBOR, MICHIGAN
# 1                  Y          242674  2016             PLANO, TEXAS
# 2                  Y          193066  2016  JERSEY CITY, NEW JERSEY
# 3                  Y          220314  2016         DENVER, COLORADO
# 4                  Y        157518.4  2016      ST. LOUIS, MISSOURI
#
#            lon         lat
# 0  -83.7430378  42.2808256
# 1  -96.6988856  33.0198431
# 2  -74.0776417  40.7281575
# 3  -104.990251  39.7392358
# 4  -90.1994042  38.6270025

# %%
df_step2 = pd.DataFrame(df_step1['WORKSITE'].str.split(', ',1).tolist(), columns = ['CITY','STATE'])
df_step2.head()                                                                                           #split city and state
# Out:
#           CITY        STATE
# 0    ANN ARBOR     MICHIGAN
# 1        PLANO        TEXAS
# 2  JERSEY CITY   NEW JERSEY
# 3       DENVER     COLORADO
# 4    ST. LOUIS     MISSOURI

# %%
df_step3 = pd.merge(df_step1, df_step2, left_index = True, right_index = True)        #merge city and state to dataframe
df_step3.head()
# Out:
#            CASE_STATUS                                      EMPLOYER_NAME  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
#   FULL_TIME_POSITION PREVAILING_WAGE  YEAR                 WORKSITE  \
# 0                  N           36067  2016      ANN ARBOR, MICHIGAN
# 1                  Y          242674  2016             PLANO, TEXAS
# 2                  Y          193066  2016  JERSEY CITY, NEW JERSEY
# 3                  Y          220314  2016         DENVER, COLORADO
# 4                  Y        157518.4  2016      ST. LOUIS, MISSOURI
#
#            lon         lat         CITY        STATE
# 0  -83.7430378  42.2808256    ANN ARBOR     MICHIGAN
# 1  -96.6988856  33.0198431        PLANO        TEXAS
# 2  -74.0776417  40.7281575  JERSEY CITY   NEW JERSEY
# 3  -104.990251  39.7392358       DENVER     COLORADO
# 4  -90.1994042  38.6270025    ST. LOUIS     MISSOURI

# %%
df_groupby_year_state = pd.DataFrame(df_step3.groupby(['YEAR','STATE']).size())
df_groupby_year_state.columns = ['COUNT']
df_groupby_year_state.head()                                   #group by year and state
# Out:
#                   COUNT
# YEAR STATE
# 2011  ALABAMA       755
#       ALASKA         96
#       ARIZONA      2563
#       ARKANSAS      922
#       CALIFORNIA  40730

# %%
df_groupby_year_state = df_groupby_year_state.groupby(level=0, group_keys=False)
df_result = df_groupby_year_state.apply(lambda x: x.sort_values('COUNT',ascending=False).head(10))
df_result.head()                   #sort data within state group
# Out:
#                   COUNT
# YEAR STATE
# 2011  CALIFORNIA  40730
#       NEW YORK    25846
#       TEXAS       19599
#       NEW JERSEY  14256
#       ILLINOIS    11290

# %%
years = set(df_result.index.get_level_values('YEAR'))
for year in years:
    df_result.loc[year].unstack(level=0).plot(kind='bar', subplots=True)
    plt.xlabel('STATE')
    plt.ylabel('COUNT')
    plt.title(str(year) + ' H-1B Visa Petitions')
    plt.show()

# %%
df_result.to_csv("final/analysis/ana_[1-5]/ana_1.csv")  #write to csv

# %% [markdown]
# ## Conclusion
# ## From the result by year, for now, the states with most H1-B opportunities are California, Texas, New York, New Jersey and Illinois.
